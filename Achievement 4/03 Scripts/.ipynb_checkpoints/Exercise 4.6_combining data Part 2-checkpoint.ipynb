# %% [markdown]
# # Task 4.6_Combining Data - Part 2

# %% [markdown]
# ### Importing libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Importing data

# %%
#Create project folder path
path=r'C:\Users\Bori\Documents\Careerfoundry\Achievement 4'

# %%
#Import the “orders_products_combined.pkl” file into Jupyter as df_ords_combined
df_ords_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared data', 'orders_products_combined.pkl'))

# %% [markdown]
# ### Check the shape of df_ords_combined

# %%
df_ords_combined.shape
# Out:
# (32434489, 13)

# %%
df_ords_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  prior_orders_by_user  \
# 0             0           0   2539329  2539329    prior                     1
# 1             0           0   2539329  2539329    prior                     1
# 2             0           0   2539329  2539329    prior                     1
# 3             0           0   2539329  2539329    prior                     1
# 4             0           0   2539329  2539329    prior                     1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# 2                  3          0   both
# 3                  4          0   both
# 4                  5          0   both

# %% [markdown]
# I checked it, the shape is the same like those of the original merged dataframe.

# %% [markdown]
# ### Merging df_ords_combined with the clean products data set

# %% [markdown]
# #### Importing dataframe

# %%
#Import the “products_checked.csv” file into Jupyter as df_prods
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'))

# %% [markdown]
# #### Checking properties

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# #### Merging datasets

# %%
df_merged_large = df_prods.merge(df_ords_combined, on = 'product_id')

# %% [markdown]
# #### Confirming the results of the merge using the merge flag.

# %%
df_merged_large
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 32404854         49692       49688      Fresh Foaming Cleanser        73
# 32404855         49692       49688      Fresh Foaming Cleanser        73
# 32404856         49692       49688      Fresh Foaming Cleanser        73
# 32404857         49692       49688      Fresh Foaming Cleanser        73
# 32404858         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  \
# 0                    19     5.8          1987          1987   3139998
# 1                    19     5.8          1989          1989   1977647
# 2                    19     5.8         11433         11433    389851
# 3                    19     5.8         12198         12198    652770
# 4                    19     5.8         12200         12200   1813452
# ...                 ...     ...           ...           ...       ...
# 32404854             11    13.5       3321928       3321928   1788356
# 32404855             11    13.5       3324686       3324686   3401313
# 32404856             11    13.5       3332310       3332310    809510
# 32404857             11    13.5       3332314       3332314   2359893
# 32404858             11    13.5       3416620       3416620   2385091
#
#           user_id eval_set  prior_orders_by_user  orders_day_of_week  \
# 0         3139998    prior                    28                   6
# 1         1977647    prior                    30                   6
# 2          389851    prior                     2                   0
# 3          652770    prior                     1                   3
# 4         1813452    prior                     3                   4
# ...           ...      ...                   ...                 ...
# 32404854  1788356    prior                     2                   0
# 32404855  3401313    prior                     1                   4
# 32404856   809510    prior                     5                   3
# 32404857  2359893    prior                     9                   3
# 32404858  2385091    prior                    11                   1
#
#           order_hour_of_day  days_since_prior_order  add_to_cart_order  \
# 0                        11                     3.0                  5
# 1                        17                    20.0                  1
# 2                        21                     6.0                 20
# 3                        13                     NaN                 10
# 4                        17                     9.0                 11
# ...                     ...                     ...                ...
# 32404854                  9                     5.0                 27
# 32404855                 11                     NaN                  5
# 32404856                  8                    15.0                 12
# 32404857                 15                     5.0                 11
# 32404858                 15                     6.0                 35
#
#           reordered _merge
# 0                 0   both
# 1                 1   both
# 2                 0   both
# 3                 0   both
# 4                 1   both
# ...             ...    ...
# 32404854          0   both
# 32404855          0   both
# 32404856          0   both
# 32404857          1   both
# 32404858          0   both
#
# [32404859 rows x 18 columns]

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# #### Exporting dataframe in suitable format

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
