# %% [markdown]
# # Exercise 4.9 - Part 1

# %% [markdown]
# ## Importing libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Importing data

# %%
#Create project folder path
path=r'C:\Users\Bori\Documents\Careerfoundry\Achievement 4'

# %%
#Import the “customers.csv” file into Jupyter as df
df = pd.read_csv(os.path.join(path, '02 Data', 'Original data', 'customers.csv'))

# %% [markdown]
# ## Descriptive analysis to discover dataframe

# %%
df.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
#Making Python show 100 rows
pd.options.display.max_rows = None

# %%
df.head(100)
# Out:
#     user_id   First Name     Surnam  Gender                 STATE  Age  \
# 0     26711      Deborah   Esquivel  Female              Missouri   48
# 1     33890     Patricia       Hart  Female            New Mexico   36
# 2     65803      Kenneth     Farley    Male                 Idaho   35
# 3    125935     Michelle      Hicks  Female                  Iowa   40
# 4    130797          Ann    Gilmore  Female              Maryland   26
# 5    133128      Cynthia      Noble  Female              Kentucky   43
# 6    152052        Chris     Walton    Male               Montana   20
# 7    168851       Joseph    Hickman    Male        South Carolina   30
# 8     69965       Jeremy       Vang    Male                 Texas   47
# 9     82820        Shawn      Chung    Male              Virginia   26
# 10    26441       Gloria   Stafford  Female                Nevada   19
# 11    33835        Roger      Casey    Male              Nebraska   45
# ...

# %%
df.shape
# Out:
# (206209, 10)

# %%
# Check frequencies of date_joined to confirm that column stores no valuable data (assumption: 1/1/2017 is stored as join data for all customers)
df['date_joined'].value_counts(dropna = False)
# Out:
# 9/17/2018     213
# 2/10/2018     212
# 4/1/2019      211
# 9/21/2019     211
# 12/19/2017    210
# 12/24/2019    209
# 1/25/2019     205
# 11/19/2019    205
# 10/11/2017    205
# 1/7/2018      205
# 12/6/2019     204
# 3/26/2018     203
# 7/28/2018     203
# 10/18/2019    203
# 3/31/2019     203
# 9/30/2019     203
# 10/20/2018    202
# 3/23/2018     202
# 11/21/2018    202
# 3/2/2020      202
# 10/6/2018     202
# 3/12/2020     202
# 10/17/2019    202
# 11/6/2018     202
# 10/18/2017    201
# 12/28/2018    201
# 2/1/2017      201
# 3/8/2019      201
# 5/4/2018      201
# 1/19/2017     200
# 11/14/2017    200
# 5/11/2018     200
# 7/23/2018     200
# 8/10/2017     199
# 1/23/2018     199
# 4/7/2018      199
# 4/13/2019     199
# 5/13/2019     198
# 9/12/2017     198
# 12/25/2017    198
# 10/23/2018    198
# 7/20/2017     198
# 9/28/2019     198
# 3/10/2017     198
# 7/7/2018      198
# 3/28/2020     197
# 1/12/2017     197
# 8/13/2018     197
# 11/12/2018    197
# 7/21/2018     197
# ...

# %% [markdown]
# My assumption failed, now we know the column stores valuable data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
df.dtypes
# Out:
# user_id          int64
# First Name      object
# Surnam          object
# Gender          object
# STATE           object
# Age              int64
# date_joined     object
# n_dependants     int64
# fam_status      object
# income           int64
# dtype: object

# %%
df.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
df.median()
# Out:
# C:\Users\Bori\AppData\Local\Temp\ipykernel_21880\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# user_id         103105.0
# Age                 49.0
# n_dependants         1.0
# income           93547.0
# dtype: float64

# %%
df.mean()
# Out:
# C:\Users\Bori\AppData\Local\Temp\ipykernel_21880\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# user_id         103105.000000
# Age                 49.501646
# n_dependants         1.499823
# income           94632.852548
# dtype: float64

# %% [markdown]
# Resulting values seem reasonable.

# %%
# Check frequencies of fam_status (data consistency check)
df['fam_status'].value_counts(dropna = False)
# Out:
# married                             144906
# single                               33962
# divorced/widowed                     17640
# living with parents and siblings      9701
# Name: fam_status, dtype: int64

# %% [markdown]
# I had certain doubts about consistency, but the above results show perfectly consistent data

# %%
#Check for mixed-types data
for col in df.columns.tolist():
    weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df[weird]) > 0:
        print(col)
# Out:
# First Name

# %% [markdown]
# Seems like the First name column has mixed-type data. Above we have seen it has some missing values. This might cause the problem.

# %%
#Checking for missing values
df.isnull().sum()
# Out:
# user_id             0
# First Name      11259
# Surnam              0
# Gender              0
# STATE               0
# Age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %% [markdown]
# The assumption is confimed, and now we know only First Name column has missing values.

# %% [markdown]
# ## Data wrangling

# %% [markdown]
# ### Renaming columns

# %%
df.rename(columns = {'fam_status' : 'family_status'}, inplace = True)

# %%
df.rename(columns = {'First Name' : 'first_name'}, inplace = True)

# %%
df.rename(columns = {'Surnam' : 'surname'}, inplace = True)

# %%
df.rename(columns = {'Gender' : 'gender'}, inplace = True)

# %%
df.rename(columns = {'STATE' : 'state'}, inplace = True)

# %%
df.rename(columns = {'Age' : 'age'}, inplace = True)

# %%
df.rename(columns = {'n_dependants' : 'dependents'}, inplace = True)

# %% [markdown]
# ### Changing data types

# %%
df['first_name'] = df['first_name'].astype('str')

# %%
df['surname'] = df['surname'].astype('str')

# %%
df['state'] = df['state'].astype('str')

# %%
df['family_status'] = df['family_status'].astype('str')

# %%
# Check frequencies of gender (data consistency check)
df['gender'].value_counts(dropna = False)
# Out:
# Male      104067
# Female    102142
# Name: gender, dtype: int64

# %%
df.head()
# Out:
#    user_id first_name   surname  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    dependents family_status  income
# 0           3       married  165665
# 1           0        single   59285
# 2           2       married   99568
# 3           0        single   42049
# 4           1       married   40374

# %%
#Checking for missing values (just confirmation)
df.isnull().sum()
# Out:
# user_id          0
# first_name       0
# surname          0
# gender           0
# state            0
# age              0
# date_joined      0
# dependents       0
# family_status    0
# income           0
# dtype: int64

# %% [markdown]
# #Find any duplicate entries in customer.csv and assign them to df_dups
# df_dups = df[df.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, surname, gender, state, age, date_joined, dependents, family_status, income]
# Index: []

# %% [markdown]
# No duplicates were found.

# %% [markdown]
# ## Combine customer data with the rest of the prepared Instacart data

# %%
#Import the “orders_products_merged_spending_loyalty_frequency.pkl” file into Jupyter as df_ords_prods_merged
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared data', 'orders_products_merged_spending_loyalty_frequency.pkl'))
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# SystemError: deallocated bytearray object has exported buffers
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[222], line 2
#       1 #Import the “orders_products_merged_spending_loyalty_frequency.pkl” file into Jupyter as df_ords_prods_merged
# ----> 2 df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared data', 'orders_products_merged_spending_loyalty_frequency.pkl'))
#
# File ~\anaconda3\lib\site-packages\pandas\io\pickle.py:208, in read_pickle(filepath_or_buffer, compression, storage_options)
#     205     with warnings.catch_warnings(record=True):
#     206         # We want to silence any warnings about, e.g. moved modules.
#     207         warnings.simplefilter("ignore", Warning)
# ...

# %%
df_ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 23 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0_x            int64
#  1   order_id                int64
#  2   user_id                 int64
#  3   eval_set                object
#  4   prior_orders_by_user    int64
#  5   orders_day_of_week      int64
#  6   order_hour_of_day       int64
#  7   days_since_prior_order  float64
#  8   product_id              int64
#  9   add_to_cart_order       int64
#  10  reordered               int64
#  11  _merge                  category
#  12  Unnamed: 0_y            int64
#  13  product_name            object
#  14  aisle_id                int64
#  15  department_id           int64
#  16  prices                  float64
#  17  max_order               int64
#  18  loyalty_flag            object
#  19  mean_price              float64
#  20  spending_flag           object
# ...

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 23)

# %% [markdown]
# The only common column is user_id, and it is the same data type in the two columns. I will join them on that. (Join consumers on the combine data set, otherwise it could lead to major data loss)

# %%
#Combining the two datasets using the user_id column
combined = df_ords_prods_merge.merge(df, on = 'user_id')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[225], line 2
#       1 #Combining the two datasets using the user_id column
# ----> 2 combined = df_ords_prods_merge.merge(df, on = 'user_id')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
# ...

# %% [markdown]
# ## Checking the resulting combined dataframe

# %%
combined.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[226], line 1
# ----> 1 combined.shape
#
# NameError: name 'combined' is not defined

# %%
combined.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[227], line 1
# ----> 1 combined.info()
#
# NameError: name 'combined' is not defined

# %%
combined.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[228], line 1
# ----> 1 combined.head()
#
# NameError: name 'combined' is not defined
